# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.autograd import Variable
from torchvision import transforms
from torch.utils import data
from PIL import Image

# %%
import cbam
class SRCNN(nn.Module):
    def __init__(self):
        super(SRCNN,self).__init__()
        self.patch_extraction=nn.Conv2d(in_channels=3,out_channels=64,kernel_size=5,stride=1,padding=4)
        self.non_linear=nn.Conv2d(in_channels=64,out_channels=32,kernel_size=1,stride=1,padding=0)
        self.cbam=cbam.CBAM(64)
        self.reconstruction=nn.Conv2d(in_channels=32,out_channels=3,kernel_size=9,stride=1,padding=2)
    def forward(self,x):
        fm_1=F.relu(self.patch_extraction(x))
        fm_2=self.cbam(fm_1)
        fm_3=F.relu(self.non_linear(fm_2))
        #此处直接删掉下面一层，后把2和4连接起来就是原模型

        fm_4=self.reconstruction(fm_3)
        return fm_4

# %%
srcnn=SRCNN()
print(srcnn)
# Out:
# SRCNN(
#   (patch_extraction): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(4, 4))
#   (non_linear): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#   (cbam): CBAM(
#     (ChannelGate): ChannelGate(
#       (mlp): Sequential(
#         (0): Flatten()
#         (1): Linear(in_features=64, out_features=4, bias=True)
#         (2): ReLU()
#         (3): Linear(in_features=4, out_features=64, bias=True)
#       )
#     )
#     (SpatialGate): SpatialGate(
#       (compress): ChannelPool()
#       (spatial): BasicConv(
#         (conv): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#         (bn): BatchNorm2d(1, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (reconstruction): Conv2d(32, 3, kernel_size=(9, 9), stride=(1, 1), padding=(2, 2))
# )

# %%
import numpy as np
transform=transforms.Compose([transforms.ToTensor(),])
class I91DataSet(data.Dataset):
    def __init__(self,root):
        imgs=os.listdir(root)
        self.imgs=[os.path.join(root,k) for k in imgs]
        self.transforms=transform
    def __getitem__(self, item):
        img_path=self.imgs[item]
        pil_img=Image.open(img_path)
        LR_pil_img=pil_img.resize((11,11),Image.BICUBIC)
        LR_pil_img=LR_pil_img.resize(pil_img.size)
        arr_LR_pil_img=np.array(LR_pil_img).astype(int)
        arr_pil_img=np.array(pil_img).astype(int)
        #print(arr_pil_img.dtype)
        #pil_img.show()
        #print(transforms.ToTensor()(LR_pil_img).dtype)
        #print(transforms.ToTensor()((arr_LR_pil_img-arr_pil_img).astype(np.float32))/255)
        #return transforms.ToTensor()(LR_pil_img),transforms.ToTensor()(pil_img)

        return transforms.ToTensor()(LR_pil_img),transforms.ToTensor()((arr_pil_img-arr_LR_pil_img).astype(np.float32))/255
    def __len__(self):
        return len(self.imgs)

# %%
dataSet=I91DataSet('CropData')
print(dataSet.__len__())
# Out:
# 3513

# %%
optimizer=optim.Adam(srcnn.parameters(),lr=0.0001)
trainLoader=data.DataLoader(dataset=dataSet,batch_size=8,shuffle=True)
criterion=nn.MSELoss()
EPOCH=160
for epoch in range(EPOCH):
    print('------------epoch {}-------------'.format(epoch))
    avg=0
    for i,(x,y) in enumerate(trainLoader):
        batch_x=Variable(x)
        batch_y=Variable(y)
        output=srcnn(batch_x)
        
        loss=criterion(output,batch_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        avg+=loss
    print(avg)
# Out:
# ------------epoch 0-------------
# tensor(0.8539, grad_fn=<AddBackward0>)
# ------------epoch 1-------------
# tensor(0.8007, grad_fn=<AddBackward0>)
# ------------epoch 2-------------
# tensor(0.7750, grad_fn=<AddBackward0>)
# ------------epoch 3-------------
# tensor(0.7595, grad_fn=<AddBackward0>)
# ------------epoch 4-------------
# tensor(0.7503, grad_fn=<AddBackward0>)
# ------------epoch 5-------------
# tensor(0.7411, grad_fn=<AddBackward0>)
# ------------epoch 6-------------
# tensor(0.7341, grad_fn=<AddBackward0>)
# ------------epoch 7-------------
# tensor(0.7288, grad_fn=<AddBackward0>)
# ------------epoch 8-------------
# tensor(0.7268, grad_fn=<AddBackward0>)
# ------------epoch 9-------------
# tensor(0.7200, grad_fn=<AddBackward0>)
# ------------epoch 10-------------
# tensor(0.7162, grad_fn=<AddBackward0>)
# ------------epoch 11-------------
# tensor(0.7132, grad_fn=<AddBackward0>)
# ------------epoch 12-------------
# tensor(0.7126, grad_fn=<AddBackward0>)
# ------------epoch 13-------------
# tensor(0.7111, grad_fn=<AddBackward0>)
# ------------epoch 14-------------
# tensor(0.7064, grad_fn=<AddBackward0>)
# ------------epoch 15-------------
# tensor(0.7051, grad_fn=<AddBackward0>)
# ------------epoch 16-------------
# tensor(0.7030, grad_fn=<AddBackward0>)
# ------------epoch 17-------------
# tensor(0.7010, grad_fn=<AddBackward0>)
# ------------epoch 18-------------
# tensor(0.6995, grad_fn=<AddBackward0>)
# ------------epoch 19-------------
# tensor(0.6978, grad_fn=<AddBackward0>)
# ------------epoch 20-------------
# tensor(0.6965, grad_fn=<AddBackward0>)
# ------------epoch 21-------------
# tensor(0.6956, grad_fn=<AddBackward0>)
# ------------epoch 22-------------
# tensor(0.6944, grad_fn=<AddBackward0>)
# ------------epoch 23-------------
# tensor(0.6936, grad_fn=<AddBackward0>)
# ------------epoch 24-------------
# tensor(0.6914, grad_fn=<AddBackward0>)
# ------------epoch 25-------------
# tensor(0.6920, grad_fn=<AddBackward0>)
# ------------epoch 26-------------
# tensor(0.6896, grad_fn=<AddBackward0>)
# ------------epoch 27-------------
# tensor(0.6883, grad_fn=<AddBackward0>)
# ------------epoch 28-------------
# tensor(0.6878, grad_fn=<AddBackward0>)
# ------------epoch 29-------------
# tensor(0.6867, grad_fn=<AddBackward0>)
# ------------epoch 30-------------
# tensor(0.6909, grad_fn=<AddBackward0>)
# ------------epoch 31-------------
# tensor(0.6870, grad_fn=<AddBackward0>)
# ------------epoch 32-------------
# tensor(0.6839, grad_fn=<AddBackward0>)
# ------------epoch 33-------------
# tensor(0.6848, grad_fn=<AddBackward0>)
# ------------epoch 34-------------
# tensor(0.6822, grad_fn=<AddBackward0>)
# ------------epoch 35-------------
# tensor(0.6828, grad_fn=<AddBackward0>)
# ------------epoch 36-------------
# tensor(0.6806, grad_fn=<AddBackward0>)
# ------------epoch 37-------------
# tensor(0.6800, grad_fn=<AddBackward0>)
# ------------epoch 38-------------
# tensor(0.6794, grad_fn=<AddBackward0>)
# ------------epoch 39-------------
# tensor(0.6805, grad_fn=<AddBackward0>)
# ------------epoch 40-------------
# tensor(0.6774, grad_fn=<AddBackward0>)
# ------------epoch 41-------------
# tensor(0.6796, grad_fn=<AddBackward0>)
# ------------epoch 42-------------
# tensor(0.6780, grad_fn=<AddBackward0>)
# ------------epoch 43-------------
# tensor(0.6763, grad_fn=<AddBackward0>)
# ------------epoch 44-------------
# tensor(0.6747, grad_fn=<AddBackward0>)
# ------------epoch 45-------------
# tensor(0.6742, grad_fn=<AddBackward0>)
# ------------epoch 46-------------
# tensor(0.6734, grad_fn=<AddBackward0>)
# ------------epoch 47-------------
# tensor(0.6776, grad_fn=<AddBackward0>)
# ------------epoch 48-------------
# tensor(0.6740, grad_fn=<AddBackward0>)
# ------------epoch 49-------------
# tensor(0.6720, grad_fn=<AddBackward0>)
# ------------epoch 50-------------
# tensor(0.6725, grad_fn=<AddBackward0>)
# ------------epoch 51-------------
# tensor(0.6712, grad_fn=<AddBackward0>)
# ------------epoch 52-------------
# tensor(0.6706, grad_fn=<AddBackward0>)
# ------------epoch 53-------------
# tensor(0.6723, grad_fn=<AddBackward0>)
# ------------epoch 54-------------
# tensor(0.6697, grad_fn=<AddBackward0>)
# ------------epoch 55-------------
# tensor(0.6686, grad_fn=<AddBackward0>)
# ------------epoch 56-------------
# tensor(0.6679, grad_fn=<AddBackward0>)
# ------------epoch 57-------------
# tensor(0.6680, grad_fn=<AddBackward0>)
# ------------epoch 58-------------
# tensor(0.6663, grad_fn=<AddBackward0>)
# ------------epoch 59-------------
# tensor(0.6668, grad_fn=<AddBackward0>)
# ------------epoch 60-------------
# tensor(0.6700, grad_fn=<AddBackward0>)
# ------------epoch 61-------------
# tensor(0.6665, grad_fn=<AddBackward0>)
# ------------epoch 62-------------
# tensor(0.6666, grad_fn=<AddBackward0>)
# ------------epoch 63-------------
# tensor(0.6673, grad_fn=<AddBackward0>)
# ------------epoch 64-------------
# tensor(0.6674, grad_fn=<AddBackward0>)
# ------------epoch 65-------------
# tensor(0.6645, grad_fn=<AddBackward0>)
# ------------epoch 66-------------
# tensor(0.6637, grad_fn=<AddBackward0>)
# ------------epoch 67-------------
# tensor(0.6633, grad_fn=<AddBackward0>)
# ------------epoch 68-------------
# tensor(0.6626, grad_fn=<AddBackward0>)
# ------------epoch 69-------------
# tensor(0.6618, grad_fn=<AddBackward0>)
# ------------epoch 70-------------
# tensor(0.6624, grad_fn=<AddBackward0>)
# ------------epoch 71-------------
# tensor(0.6610, grad_fn=<AddBackward0>)
# ------------epoch 72-------------
# tensor(0.6616, grad_fn=<AddBackward0>)
# ------------epoch 73-------------
# tensor(0.6652, grad_fn=<AddBackward0>)
# ------------epoch 74-------------
# tensor(0.6605, grad_fn=<AddBackward0>)
# ------------epoch 75-------------
# tensor(0.6600, grad_fn=<AddBackward0>)
# ------------epoch 76-------------
# tensor(0.6594, grad_fn=<AddBackward0>)
# ------------epoch 77-------------
# tensor(0.6590, grad_fn=<AddBackward0>)
# ------------epoch 78-------------
# tensor(0.6585, grad_fn=<AddBackward0>)
# ------------epoch 79-------------
# tensor(0.6594, grad_fn=<AddBackward0>)
# ------------epoch 80-------------
# tensor(0.6582, grad_fn=<AddBackward0>)
# ------------epoch 81-------------
# tensor(0.6583, grad_fn=<AddBackward0>)
# ------------epoch 82-------------
# tensor(0.6583, grad_fn=<AddBackward0>)
# ------------epoch 83-------------
# tensor(0.6571, grad_fn=<AddBackward0>)
# ------------epoch 84-------------
# tensor(0.6572, grad_fn=<AddBackward0>)
# ------------epoch 85-------------
# tensor(0.6576, grad_fn=<AddBackward0>)
# ------------epoch 86-------------
# tensor(0.6569, grad_fn=<AddBackward0>)
# ------------epoch 87-------------
# tensor(0.6570, grad_fn=<AddBackward0>)
# ------------epoch 88-------------
# tensor(0.6560, grad_fn=<AddBackward0>)
# ------------epoch 89-------------
# tensor(0.6556, grad_fn=<AddBackward0>)
# ------------epoch 90-------------
# tensor(0.6552, grad_fn=<AddBackward0>)
# ------------epoch 91-------------
# tensor(0.6556, grad_fn=<AddBackward0>)
# ------------epoch 92-------------
# tensor(0.6570, grad_fn=<AddBackward0>)
# ------------epoch 93-------------
# tensor(0.6550, grad_fn=<AddBackward0>)
# ------------epoch 94-------------
# tensor(0.6540, grad_fn=<AddBackward0>)
# ------------epoch 95-------------
# tensor(0.6535, grad_fn=<AddBackward0>)
# ------------epoch 96-------------
# tensor(0.6538, grad_fn=<AddBackward0>)
# ------------epoch 97-------------
# tensor(0.6532, grad_fn=<AddBackward0>)
# ------------epoch 98-------------
# tensor(0.6531, grad_fn=<AddBackward0>)
# ------------epoch 99-------------
# tensor(0.6528, grad_fn=<AddBackward0>)
# ------------epoch 100-------------
# tensor(0.6525, grad_fn=<AddBackward0>)
# ------------epoch 101-------------
# tensor(0.6522, grad_fn=<AddBackward0>)
# ------------epoch 102-------------
# tensor(0.6518, grad_fn=<AddBackward0>)
# ------------epoch 103-------------
# tensor(0.6517, grad_fn=<AddBackward0>)
# ------------epoch 104-------------
# tensor(0.6548, grad_fn=<AddBackward0>)
# ------------epoch 105-------------
# tensor(0.6547, grad_fn=<AddBackward0>)
# ------------epoch 106-------------
# tensor(0.6525, grad_fn=<AddBackward0>)
# ------------epoch 107-------------
# tensor(0.6516, grad_fn=<AddBackward0>)
# ------------epoch 108-------------
# tensor(0.6507, grad_fn=<AddBackward0>)
# ------------epoch 109-------------
# tensor(0.6503, grad_fn=<AddBackward0>)
# ------------epoch 110-------------
# tensor(0.6520, grad_fn=<AddBackward0>)
# ------------epoch 111-------------
# tensor(0.6517, grad_fn=<AddBackward0>)
# ------------epoch 112-------------
# tensor(0.6502, grad_fn=<AddBackward0>)
# ------------epoch 113-------------
# tensor(0.6491, grad_fn=<AddBackward0>)
# ------------epoch 114-------------
# tensor(0.6486, grad_fn=<AddBackward0>)
# ------------epoch 115-------------
# tensor(0.6492, grad_fn=<AddBackward0>)
# ------------epoch 116-------------
# tensor(0.6484, grad_fn=<AddBackward0>)
# ------------epoch 117-------------
# tensor(0.6489, grad_fn=<AddBackward0>)
# ------------epoch 118-------------
# tensor(0.6487, grad_fn=<AddBackward0>)
# ------------epoch 119-------------
# tensor(0.6486, grad_fn=<AddBackward0>)
# ------------epoch 120-------------
# tensor(0.6539, grad_fn=<AddBackward0>)
# ------------epoch 121-------------
# tensor(0.6495, grad_fn=<AddBackward0>)
# ------------epoch 122-------------
# tensor(0.6471, grad_fn=<AddBackward0>)
# ------------epoch 123-------------
# tensor(0.6466, grad_fn=<AddBackward0>)
# ------------epoch 124-------------
# tensor(0.6481, grad_fn=<AddBackward0>)
# ------------epoch 125-------------
# tensor(0.6510, grad_fn=<AddBackward0>)
# ------------epoch 126-------------
# tensor(0.6484, grad_fn=<AddBackward0>)
# ------------epoch 127-------------
# tensor(0.6463, grad_fn=<AddBackward0>)
# ------------epoch 128-------------
# tensor(0.6466, grad_fn=<AddBackward0>)
# ------------epoch 129-------------
# tensor(0.6491, grad_fn=<AddBackward0>)
# ------------epoch 130-------------
# tensor(0.6460, grad_fn=<AddBackward0>)
# ------------epoch 131-------------
# tensor(0.6459, grad_fn=<AddBackward0>)
# ------------epoch 132-------------
# tensor(0.6474, grad_fn=<AddBackward0>)
# ------------epoch 133-------------
# tensor(0.6456, grad_fn=<AddBackward0>)
# ------------epoch 134-------------
# tensor(0.6466, grad_fn=<AddBackward0>)
# ------------epoch 135-------------
# tensor(0.6457, grad_fn=<AddBackward0>)
# ------------epoch 136-------------
# tensor(0.6468, grad_fn=<AddBackward0>)
# ------------epoch 137-------------
# tensor(0.6467, grad_fn=<AddBackward0>)
# ------------epoch 138-------------
# tensor(0.6446, grad_fn=<AddBackward0>)
# ------------epoch 139-------------
# tensor(0.6445, grad_fn=<AddBackward0>)
# ------------epoch 140-------------
# tensor(0.6455, grad_fn=<AddBackward0>)
# ------------epoch 141-------------
# tensor(0.6438, grad_fn=<AddBackward0>)
# ------------epoch 142-------------
# tensor(0.6466, grad_fn=<AddBackward0>)
# ------------epoch 143-------------
# tensor(0.6444, grad_fn=<AddBackward0>)
# ------------epoch 144-------------
# tensor(0.6442, grad_fn=<AddBackward0>)
# ------------epoch 145-------------
# tensor(0.6438, grad_fn=<AddBackward0>)
# ------------epoch 146-------------
# tensor(0.6433, grad_fn=<AddBackward0>)
# ------------epoch 147-------------
# tensor(0.6453, grad_fn=<AddBackward0>)
# ------------epoch 148-------------
# tensor(0.6426, grad_fn=<AddBackward0>)
# ------------epoch 149-------------
# tensor(0.6436, grad_fn=<AddBackward0>)
# ------------epoch 150-------------
# tensor(0.6451, grad_fn=<AddBackward0>)
# ------------epoch 151-------------
# tensor(0.6425, grad_fn=<AddBackward0>)
# ------------epoch 152-------------
# tensor(0.6429, grad_fn=<AddBackward0>)
# ------------epoch 153-------------
# tensor(0.6427, grad_fn=<AddBackward0>)
# ------------epoch 154-------------
# tensor(0.6428, grad_fn=<AddBackward0>)
# ------------epoch 155-------------
# tensor(0.6420, grad_fn=<AddBackward0>)
# ------------epoch 156-------------
# tensor(0.6457, grad_fn=<AddBackward0>)
# ------------epoch 157-------------
# tensor(0.6479, grad_fn=<AddBackward0>)
# ------------epoch 158-------------
# tensor(0.6435, grad_fn=<AddBackward0>)
# ------------epoch 159-------------
# tensor(0.6464, grad_fn=<AddBackward0>)
# /home/yuki/anaconda3/envs/pytorch-en/lib/python3.8/site-packages/torch/nn/functional.py:1709: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
#srcnn=torch.load("srcnn+res+cbam1.pkl")
#197*176
pil_test=Image.open('t1.bmp')
pil_test_y=transforms.ToTensor()(pil_test)
pil_test_y=pil_test_y.unsqueeze(0)
LR_pil_test=pil_test.resize((197//3,176//3),Image.BICUBIC)
LR_pil_test=LR_pil_test.resize(pil_test.size)

#LR_pil_test.show()
#tensor_test=transforms.ToTensor()(LR_pil_test)
LR_pil_test.save('sourcet1.jpg')
LR_pil_test=Image.open("sourcet1.jpg")
tensor_test=transforms.ToTensor()(LR_pil_test)
tensor_test=tensor_test.unsqueeze(0)
print(tensor_test)
tensor_test_y=srcnn(tensor_test)
tensor_test_y=tensor_test_y+tensor_test
print(tensor_test_y)
loss=criterion(tensor_test_y,pil_test_y)
print(loss*100)
loss=criterion(tensor_test,pil_test_y)
print(loss*100)
tensor_test_y=tensor_test_y.squeeze(0)
result=transforms.ToPILImage()(tensor_test_y)
result.show()
result.save('resultt1.jpg')
# Out:
# tensor([[[[0.5333, 0.5333, 0.5333,  ..., 0.0824, 0.0824, 0.0824],
#           [0.5294, 0.5333, 0.5373,  ..., 0.0824, 0.0824, 0.0824],
#           [0.5294, 0.5333, 0.5412,  ..., 0.0824, 0.0824, 0.0824],
#           ...,
#           [0.2824, 0.2824, 0.2863,  ..., 0.7412, 0.7333, 0.7373],
#           [0.2784, 0.2824, 0.2863,  ..., 0.7451, 0.7451, 0.7490],
#           [0.2745, 0.2784, 0.2863,  ..., 0.7490, 0.7490, 0.7529]],
#
#          [[0.1961, 0.1882, 0.1922,  ..., 0.0902, 0.0902, 0.0902],
#           [0.1922, 0.1922, 0.1961,  ..., 0.0902, 0.0902, 0.0902],
#           [0.1922, 0.1961, 0.2000,  ..., 0.0902, 0.0902, 0.0902],
#           ...,
#           [0.1765, 0.1765, 0.1804,  ..., 0.5647, 0.5569, 0.5608],
#           [0.1725, 0.1765, 0.1804,  ..., 0.5686, 0.5686, 0.5725],
#           [0.1686, 0.1725, 0.1804,  ..., 0.5725, 0.5725, 0.5765]],
#
#          [[0.5843, 0.5804, 0.5725,  ..., 0.0392, 0.0392, 0.0392],
#           [0.5804, 0.5725, 0.5765,  ..., 0.0392, 0.0392, 0.0392],
#           [0.5725, 0.5765, 0.5804,  ..., 0.0392, 0.0392, 0.0392],
#           ...,
#           [0.3529, 0.3529, 0.3569,  ..., 0.7255, 0.7176, 0.7216],
#           [0.3490, 0.3529, 0.3569,  ..., 0.7216, 0.7216, 0.7255],
#           [0.3451, 0.3490, 0.3569,  ..., 0.7255, 0.7255, 0.7294]]]])
# tensor([[[[0.5448, 0.5323, 0.4983,  ..., 0.0709, 0.0826, 0.0982],
#           [0.5627, 0.5182, 0.4989,  ..., 0.0812, 0.0764, 0.0953],
#           [0.5472, 0.5054, 0.5154,  ..., 0.0756, 0.0754, 0.0862],
#           ...,
#           [0.3000, 0.2742, 0.2745,  ..., 0.7271, 0.7357, 0.7497],
#           [0.2763, 0.2577, 0.2522,  ..., 0.7225, 0.7631, 0.7923],
#           [0.2609, 0.2504, 0.2583,  ..., 0.7361, 0.7809, 0.7912]],
#
#          [[0.2021, 0.1853, 0.1503,  ..., 0.0834, 0.0922, 0.1020],
#           [0.2196, 0.1782, 0.1553,  ..., 0.0895, 0.0847, 0.0952],
#           [0.2052, 0.1699, 0.1773,  ..., 0.0870, 0.0857, 0.0884],
#           ...,
#           [0.1932, 0.1663, 0.1719,  ..., 0.5487, 0.5503, 0.5653],
#           [0.1671, 0.1505, 0.1492,  ..., 0.5468, 0.5830, 0.6116],
#           [0.1555, 0.1483, 0.1552,  ..., 0.5632, 0.6061, 0.6082]],
#
#          [[0.5965, 0.5816, 0.5437,  ..., 0.0389, 0.0427, 0.0467],
#           [0.6101, 0.5601, 0.5533,  ..., 0.0464, 0.0393, 0.0422],
#           [0.5889, 0.5522, 0.5696,  ..., 0.0407, 0.0415, 0.0377],
#           ...,
#           [0.3625, 0.3406, 0.3646,  ..., 0.7278, 0.7282, 0.7318],
#           [0.3417, 0.3298, 0.3419,  ..., 0.7129, 0.7426, 0.7661],
#           [0.3250, 0.3265, 0.3399,  ..., 0.7224, 0.7625, 0.7716]]]],
#        grad_fn=<AddBackward0>)
# tensor(0.1304, grad_fn=<MulBackward0>)
# tensor(0.1633)

# %%
torch.save(srcnn, 'srcnn+res+cbam33.pkl')
print("123")
# Out:
# 123
