# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.autograd import Variable
from torchvision import transforms
from torch.utils import data
from PIL import Image

# %%
import cbam
class SRCNN(nn.Module):
    def __init__(self):
        super(SRCNN,self).__init__()
        self.patch_extraction=nn.Conv2d(in_channels=3,out_channels=64,kernel_size=5,stride=1,padding=4)
        self.non_linear=nn.Conv2d(in_channels=64,out_channels=32,kernel_size=1,stride=1,padding=0)
        self.reconstruction=nn.Conv2d(in_channels=32,out_channels=3,kernel_size=9,stride=1,padding=2)
    def forward(self,x):
        fm_1=F.relu(self.patch_extraction(x))
        fm_2=F.relu(self.non_linear(fm_1))
        #fm_3=self.cbam(fm_2)
        fm_4=self.reconstruction(fm_2)
        return fm_4

# %%
srcnn=SRCNN()
print(srcnn)
# Out:
# SRCNN(
#   (patch_extraction): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(4, 4))
#   (non_linear): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#   (reconstruction): Conv2d(32, 3, kernel_size=(9, 9), stride=(1, 1), padding=(2, 2))
# )

# %%
import numpy as np
transform=transforms.Compose([transforms.ToTensor(),])
class I91DataSet(data.Dataset):
    def __init__(self,root):
        imgs=os.listdir(root)
        self.imgs=[os.path.join(root,k) for k in imgs]
        self.transforms=transform
    def __getitem__(self, item):
        img_path=self.imgs[item]
        pil_img=Image.open(img_path)
        LR_pil_img=pil_img.resize((11,11),Image.BICUBIC)
        LR_pil_img=LR_pil_img.resize(pil_img.size)
        arr_LR_pil_img=np.array(LR_pil_img).astype(int)
        arr_pil_img=np.array(pil_img).astype(int)
        #print(arr_pil_img.dtype)
        #pil_img.show()
        #print(transforms.ToTensor()(LR_pil_img).dtype)
        #print(transforms.ToTensor()((arr_LR_pil_img-arr_pil_img).astype(np.float32))/255)
        return transforms.ToTensor()(LR_pil_img),transforms.ToTensor()(pil_img)

        #return transforms.ToTensor()(LR_pil_img),transforms.ToTensor()((arr_pil_img-arr_LR_pil_img).astype(np.float32))/255
    def __len__(self):
        return len(self.imgs)

# %%
dataSet=I91DataSet('CropData')
print(dataSet.__len__())
# Out:
# 3513

# %%
optimizer=optim.Adam(srcnn.parameters(),lr=0.0001)
trainLoader=data.DataLoader(dataset=dataSet,batch_size=8,shuffle=True)
criterion=nn.MSELoss()
EPOCH=200
for epoch in range(EPOCH):
    print('------------epoch {}-------------'.format(epoch))
    avg=0
    for i,(x,y) in enumerate(trainLoader):
        batch_x=Variable(x)
        batch_y=Variable(y)
        output=srcnn(batch_x)
        
        loss=criterion(output,batch_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        avg+=loss
    print(avg)
# Out:
# ------------epoch 0-------------
# tensor(8.9957, grad_fn=<AddBackward0>)
# ------------epoch 1-------------
# tensor(1.3880, grad_fn=<AddBackward0>)
# ------------epoch 2-------------
# tensor(1.1069, grad_fn=<AddBackward0>)
# ------------epoch 3-------------
# tensor(0.9727, grad_fn=<AddBackward0>)
# ------------epoch 4-------------
# tensor(0.9013, grad_fn=<AddBackward0>)
# ------------epoch 5-------------
# tensor(0.8703, grad_fn=<AddBackward0>)
# ------------epoch 6-------------
# tensor(0.8451, grad_fn=<AddBackward0>)
# ------------epoch 7-------------
# tensor(0.8330, grad_fn=<AddBackward0>)
# ------------epoch 8-------------
# tensor(0.8191, grad_fn=<AddBackward0>)
# ------------epoch 9-------------
# tensor(0.8126, grad_fn=<AddBackward0>)
# ------------epoch 10-------------
# tensor(0.8028, grad_fn=<AddBackward0>)
# ------------epoch 11-------------
# tensor(0.7986, grad_fn=<AddBackward0>)
# ------------epoch 12-------------
# tensor(0.7936, grad_fn=<AddBackward0>)
# ------------epoch 13-------------
# tensor(0.7864, grad_fn=<AddBackward0>)
# ------------epoch 14-------------
# tensor(0.7799, grad_fn=<AddBackward0>)
# ------------epoch 15-------------
# tensor(0.7780, grad_fn=<AddBackward0>)
# ------------epoch 16-------------
# tensor(0.7747, grad_fn=<AddBackward0>)
# ------------epoch 17-------------
# tensor(0.7800, grad_fn=<AddBackward0>)
# ------------epoch 18-------------
# tensor(0.7684, grad_fn=<AddBackward0>)
# ------------epoch 19-------------
# tensor(0.7625, grad_fn=<AddBackward0>)
# ------------epoch 20-------------
# tensor(0.7576, grad_fn=<AddBackward0>)
# ------------epoch 21-------------
# tensor(0.7571, grad_fn=<AddBackward0>)
# ------------epoch 22-------------
# tensor(0.7512, grad_fn=<AddBackward0>)
# ------------epoch 23-------------
# tensor(0.7465, grad_fn=<AddBackward0>)
# ------------epoch 24-------------
# tensor(0.7485, grad_fn=<AddBackward0>)
# ------------epoch 25-------------
# tensor(0.7408, grad_fn=<AddBackward0>)
# ------------epoch 26-------------
# tensor(0.7441, grad_fn=<AddBackward0>)
# ------------epoch 27-------------
# tensor(0.7367, grad_fn=<AddBackward0>)
# ------------epoch 28-------------
# tensor(0.7352, grad_fn=<AddBackward0>)
# ------------epoch 29-------------
# tensor(0.7352, grad_fn=<AddBackward0>)
# ------------epoch 30-------------
# tensor(0.7302, grad_fn=<AddBackward0>)
# ------------epoch 31-------------
# tensor(0.7304, grad_fn=<AddBackward0>)
# ------------epoch 32-------------
# tensor(0.7317, grad_fn=<AddBackward0>)
# ------------epoch 33-------------
# tensor(0.7245, grad_fn=<AddBackward0>)
# ------------epoch 34-------------
# tensor(0.7237, grad_fn=<AddBackward0>)
# ------------epoch 35-------------
# tensor(0.7262, grad_fn=<AddBackward0>)
# ------------epoch 36-------------
# tensor(0.7213, grad_fn=<AddBackward0>)
# ------------epoch 37-------------
# tensor(0.7273, grad_fn=<AddBackward0>)
# ------------epoch 38-------------
# tensor(0.7194, grad_fn=<AddBackward0>)
# ------------epoch 39-------------
# tensor(0.7186, grad_fn=<AddBackward0>)
# ------------epoch 40-------------
# tensor(0.7196, grad_fn=<AddBackward0>)
# ------------epoch 41-------------
# tensor(0.7168, grad_fn=<AddBackward0>)
# ------------epoch 42-------------
# tensor(0.7159, grad_fn=<AddBackward0>)
# ------------epoch 43-------------
# tensor(0.7174, grad_fn=<AddBackward0>)
# ------------epoch 44-------------
# tensor(0.7137, grad_fn=<AddBackward0>)
# ------------epoch 45-------------
# tensor(0.7170, grad_fn=<AddBackward0>)
# ------------epoch 46-------------
# tensor(0.7274, grad_fn=<AddBackward0>)
# ------------epoch 47-------------
# tensor(0.7122, grad_fn=<AddBackward0>)
# ------------epoch 48-------------
# tensor(0.7138, grad_fn=<AddBackward0>)
# ------------epoch 49-------------
# tensor(0.7125, grad_fn=<AddBackward0>)
# ------------epoch 50-------------
# tensor(0.7100, grad_fn=<AddBackward0>)
# ------------epoch 51-------------
# tensor(0.7058, grad_fn=<AddBackward0>)
# ------------epoch 52-------------
# tensor(0.7103, grad_fn=<AddBackward0>)
# ------------epoch 53-------------
# tensor(0.7098, grad_fn=<AddBackward0>)
# ------------epoch 54-------------
# tensor(0.7031, grad_fn=<AddBackward0>)
# ------------epoch 55-------------
# tensor(0.7037, grad_fn=<AddBackward0>)
# ------------epoch 56-------------
# tensor(0.7078, grad_fn=<AddBackward0>)
# ------------epoch 57-------------
# tensor(0.7071, grad_fn=<AddBackward0>)
# ------------epoch 58-------------
# tensor(0.7007, grad_fn=<AddBackward0>)
# ------------epoch 59-------------
# tensor(0.7012, grad_fn=<AddBackward0>)
# ------------epoch 60-------------
# tensor(0.7013, grad_fn=<AddBackward0>)
# ------------epoch 61-------------
# tensor(0.7006, grad_fn=<AddBackward0>)
# ------------epoch 62-------------
# tensor(0.6997, grad_fn=<AddBackward0>)
# ------------epoch 63-------------
# tensor(0.6980, grad_fn=<AddBackward0>)
# ------------epoch 64-------------
# tensor(0.6982, grad_fn=<AddBackward0>)
# ------------epoch 65-------------
# tensor(0.6960, grad_fn=<AddBackward0>)
# ------------epoch 66-------------
# tensor(0.7041, grad_fn=<AddBackward0>)
# ------------epoch 67-------------
# tensor(0.6952, grad_fn=<AddBackward0>)
# ------------epoch 68-------------
# tensor(0.6953, grad_fn=<AddBackward0>)
# ------------epoch 69-------------
# tensor(0.6957, grad_fn=<AddBackward0>)
# ------------epoch 70-------------
# tensor(0.6943, grad_fn=<AddBackward0>)
# ------------epoch 71-------------
# tensor(0.6954, grad_fn=<AddBackward0>)
# ------------epoch 72-------------
# tensor(0.6940, grad_fn=<AddBackward0>)
# ------------epoch 73-------------
# tensor(0.6924, grad_fn=<AddBackward0>)
# ------------epoch 74-------------
# tensor(0.6916, grad_fn=<AddBackward0>)
# ------------epoch 75-------------
# tensor(0.6903, grad_fn=<AddBackward0>)
# ------------epoch 76-------------
# tensor(0.7006, grad_fn=<AddBackward0>)
# ------------epoch 77-------------
# tensor(0.6924, grad_fn=<AddBackward0>)
# ------------epoch 78-------------
# tensor(0.6956, grad_fn=<AddBackward0>)
# ------------epoch 79-------------
# tensor(0.6906, grad_fn=<AddBackward0>)
# ------------epoch 80-------------
# tensor(0.6905, grad_fn=<AddBackward0>)
# ------------epoch 81-------------
# tensor(0.6898, grad_fn=<AddBackward0>)
# ------------epoch 82-------------
# tensor(0.6890, grad_fn=<AddBackward0>)
# ------------epoch 83-------------
# tensor(0.6886, grad_fn=<AddBackward0>)
# ------------epoch 84-------------
# tensor(0.6920, grad_fn=<AddBackward0>)
# ------------epoch 85-------------
# tensor(0.6928, grad_fn=<AddBackward0>)
# ------------epoch 86-------------
# tensor(0.6882, grad_fn=<AddBackward0>)
# ------------epoch 87-------------
# tensor(0.6865, grad_fn=<AddBackward0>)
# ------------epoch 88-------------
# tensor(0.6867, grad_fn=<AddBackward0>)
# ------------epoch 89-------------
# tensor(0.6874, grad_fn=<AddBackward0>)
# ------------epoch 90-------------
# tensor(0.6852, grad_fn=<AddBackward0>)
# ------------epoch 91-------------
# tensor(0.6872, grad_fn=<AddBackward0>)
# ------------epoch 92-------------
# tensor(0.6842, grad_fn=<AddBackward0>)
# ------------epoch 93-------------
# tensor(0.6857, grad_fn=<AddBackward0>)
# ------------epoch 94-------------
# tensor(0.6841, grad_fn=<AddBackward0>)
# ------------epoch 95-------------
# tensor(0.6871, grad_fn=<AddBackward0>)
# ------------epoch 96-------------
# tensor(0.6833, grad_fn=<AddBackward0>)
# ------------epoch 97-------------
# tensor(0.6910, grad_fn=<AddBackward0>)
# ------------epoch 98-------------
# tensor(0.6826, grad_fn=<AddBackward0>)
# ------------epoch 99-------------
# tensor(0.6842, grad_fn=<AddBackward0>)
# ------------epoch 100-------------
# tensor(0.6826, grad_fn=<AddBackward0>)
# ------------epoch 101-------------
# tensor(0.6822, grad_fn=<AddBackward0>)
# ------------epoch 102-------------
# tensor(0.6820, grad_fn=<AddBackward0>)
# ------------epoch 103-------------
# tensor(0.6824, grad_fn=<AddBackward0>)
# ------------epoch 104-------------
# tensor(0.6815, grad_fn=<AddBackward0>)
# ------------epoch 105-------------
# tensor(0.6829, grad_fn=<AddBackward0>)
# ------------epoch 106-------------
# tensor(0.6836, grad_fn=<AddBackward0>)
# ------------epoch 107-------------
# tensor(0.6797, grad_fn=<AddBackward0>)
# ------------epoch 108-------------
# tensor(0.6841, grad_fn=<AddBackward0>)
# ------------epoch 109-------------
# tensor(0.6804, grad_fn=<AddBackward0>)
# ------------epoch 110-------------
# tensor(0.6815, grad_fn=<AddBackward0>)
# ------------epoch 111-------------
# tensor(0.6788, grad_fn=<AddBackward0>)
# ------------epoch 112-------------
# tensor(0.6786, grad_fn=<AddBackward0>)
# ------------epoch 113-------------
# tensor(0.6795, grad_fn=<AddBackward0>)
# ------------epoch 114-------------
# tensor(0.6813, grad_fn=<AddBackward0>)
# ------------epoch 115-------------
# tensor(0.6809, grad_fn=<AddBackward0>)
# ------------epoch 116-------------
# tensor(0.6767, grad_fn=<AddBackward0>)
# ------------epoch 117-------------
# tensor(0.6832, grad_fn=<AddBackward0>)
# ------------epoch 118-------------
# tensor(0.6868, grad_fn=<AddBackward0>)
# ------------epoch 119-------------
# tensor(0.6791, grad_fn=<AddBackward0>)
# ------------epoch 120-------------
# tensor(0.6805, grad_fn=<AddBackward0>)
# ------------epoch 121-------------
# tensor(0.6823, grad_fn=<AddBackward0>)
# ------------epoch 122-------------
# tensor(0.6772, grad_fn=<AddBackward0>)
# ------------epoch 123-------------
# tensor(0.6795, grad_fn=<AddBackward0>)
# ------------epoch 124-------------
# tensor(0.6753, grad_fn=<AddBackward0>)
# ------------epoch 125-------------
# tensor(0.6767, grad_fn=<AddBackward0>)
# ------------epoch 126-------------
# tensor(0.6765, grad_fn=<AddBackward0>)
# ------------epoch 127-------------
# tensor(0.6755, grad_fn=<AddBackward0>)
# ------------epoch 128-------------
# tensor(0.6810, grad_fn=<AddBackward0>)
# ------------epoch 129-------------
# tensor(0.6746, grad_fn=<AddBackward0>)
# ------------epoch 130-------------
# tensor(0.6747, grad_fn=<AddBackward0>)
# ------------epoch 131-------------
# tensor(0.6760, grad_fn=<AddBackward0>)
# ------------epoch 132-------------
# tensor(0.6764, grad_fn=<AddBackward0>)
# ------------epoch 133-------------
# tensor(0.6748, grad_fn=<AddBackward0>)
# ------------epoch 134-------------
# tensor(0.6758, grad_fn=<AddBackward0>)
# ------------epoch 135-------------
# tensor(0.6760, grad_fn=<AddBackward0>)
# ------------epoch 136-------------
# tensor(0.6748, grad_fn=<AddBackward0>)
# ------------epoch 137-------------
# tensor(0.6784, grad_fn=<AddBackward0>)
# ------------epoch 138-------------
# tensor(0.6739, grad_fn=<AddBackward0>)
# ------------epoch 139-------------
# tensor(0.6740, grad_fn=<AddBackward0>)
# ------------epoch 140-------------
# tensor(0.6758, grad_fn=<AddBackward0>)
# ------------epoch 141-------------
# tensor(0.6756, grad_fn=<AddBackward0>)
# ------------epoch 142-------------
# tensor(0.6747, grad_fn=<AddBackward0>)
# ------------epoch 143-------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b42af4caa546> in <module>
#       6     print('------------epoch {}-------------'.format(epoch))
#       7     avg=0
# ----> 8     for i,(x,y) in enumerate(trainLoader):
#       9         batch_x=Variable(x)
#      10         batch_y=Variable(y)
#
# ~/anaconda3/envs/pytorch-en/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/pytorch-en/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     555     def _next_data(self):
#     556         index = self._next_index()  # may raise StopIteration
# --> 557         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     558         if self._pin_memory:
#     559             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/envs/pytorch-en/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/pytorch-en/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-4-0baeebc3b41a> in __getitem__(self, item)
#       9         img_path=self.imgs[item]
#      10         pil_img=Image.open(img_path)
# ---> 11         LR_pil_img=pil_img.resize((11,11),Image.BICUBIC)
#      12         LR_pil_img=LR_pil_img.resize(pil_img.size)
#      13         arr_LR_pil_img=np.array(LR_pil_img).astype(int)
#
# KeyboardInterrupt:

# %%
#197*176
pil_test=Image.open('t1.bmp')
pil_test_y=transforms.ToTensor()(pil_test)
pil_test_y=pil_test_y.unsqueeze(0)
LR_pil_test=pil_test.resize((197//3,176//3),Image.BICUBIC)
LR_pil_test=LR_pil_test.resize(pil_test.size)

#LR_pil_test.show()
tensor_test=transforms.ToTensor()(LR_pil_test)
LR_pil_test=LR_pil_test.save('sourcet1.jpg')
tensor_test=tensor_test.unsqueeze(0)
print(tensor_test)
tensor_test_y=srcnn(tensor_test)
#tensor_test_y=tensor_test_y+tensor_test
print(tensor_test_y)
loss=criterion(tensor_test_y,pil_test_y)
print(loss*100)
loss=criterion(tensor_test,pil_test_y)
print(loss*100)
tensor_test_y=tensor_test_y.squeeze(0)
result=transforms.ToPILImage()(tensor_test_y)
result.show()
result.save('resultt1.jpg')
# Out:
# tensor([[[[0.5333, 0.5373, 0.5451,  ..., 0.0784, 0.0824, 0.0824],
#           [0.5373, 0.5412, 0.5490,  ..., 0.0784, 0.0824, 0.0824],
#           [0.5412, 0.5451, 0.5529,  ..., 0.0784, 0.0824, 0.0824],
#           ...,
#           [0.2745, 0.2784, 0.2824,  ..., 0.7412, 0.7373, 0.7333],
#           [0.2627, 0.2667, 0.2745,  ..., 0.7490, 0.7451, 0.7412],
#           [0.2588, 0.2627, 0.2706,  ..., 0.7529, 0.7490, 0.7451]],
#
#          [[0.1804, 0.1843, 0.1922,  ..., 0.0902, 0.0941, 0.0941],
#           [0.1843, 0.1882, 0.1961,  ..., 0.0902, 0.0941, 0.0941],
#           [0.1961, 0.2000, 0.2039,  ..., 0.0902, 0.0941, 0.0941],
#           ...,
#           [0.1843, 0.1804, 0.1804,  ..., 0.5647, 0.5647, 0.5647],
#           [0.1843, 0.1843, 0.1843,  ..., 0.5725, 0.5765, 0.5765],
#           [0.1843, 0.1843, 0.1882,  ..., 0.5765, 0.5804, 0.5804]],
#
#          [[0.5529, 0.5569, 0.5686,  ..., 0.0275, 0.0314, 0.0314],
#           [0.5569, 0.5608, 0.5725,  ..., 0.0275, 0.0314, 0.0314],
#           [0.5686, 0.5725, 0.5804,  ..., 0.0275, 0.0314, 0.0314],
#           ...,
#           [0.3412, 0.3412, 0.3451,  ..., 0.7333, 0.7333, 0.7333],
#           [0.3412, 0.3412, 0.3451,  ..., 0.7412, 0.7412, 0.7412],
#           [0.3412, 0.3412, 0.3451,  ..., 0.7451, 0.7451, 0.7451]]]])
# tensor([[[[0.5190, 0.5279, 0.5268,  ..., 0.0810, 0.0880, 0.1049],
#           [0.5329, 0.5435, 0.5506,  ..., 0.0813, 0.0805, 0.0888],
#           [0.5254, 0.5452, 0.5527,  ..., 0.0792, 0.0706, 0.0753],
#           ...,
#           [0.2710, 0.2761, 0.2732,  ..., 0.7520, 0.7452, 0.7187],
#           [0.2500, 0.2531, 0.2639,  ..., 0.7706, 0.7653, 0.7246],
#           [0.2626, 0.2545, 0.2750,  ..., 0.7696, 0.7549, 0.7356]],
#
#          [[0.1856, 0.1793, 0.1854,  ..., 0.0922, 0.0949, 0.1017],
#           [0.1842, 0.1793, 0.1993,  ..., 0.0892, 0.0947, 0.0971],
#           [0.1916, 0.1864, 0.2175,  ..., 0.0856, 0.0858, 0.0915],
#           ...,
#           [0.1762, 0.1738, 0.1857,  ..., 0.5714, 0.5754, 0.5566],
#           [0.1762, 0.1721, 0.1854,  ..., 0.5884, 0.5884, 0.5617],
#           [0.1939, 0.1817, 0.1904,  ..., 0.5863, 0.5865, 0.5760]],
#
#          [[0.5073, 0.5365, 0.5608,  ..., 0.0271, 0.0327, 0.0362],
#           [0.5327, 0.5630, 0.5860,  ..., 0.0322, 0.0329, 0.0291],
#           [0.5510, 0.5809, 0.5926,  ..., 0.0295, 0.0283, 0.0225],
#           ...,
#           [0.3418, 0.3426, 0.3482,  ..., 0.7484, 0.7544, 0.7306],
#           [0.3350, 0.3430, 0.3555,  ..., 0.7688, 0.7641, 0.7270],
#           [0.3302, 0.3413, 0.3519,  ..., 0.7575, 0.7486, 0.7198]]]],
#        grad_fn=<MkldnnConvolutionBackward>)
# tensor(0.1119, grad_fn=<MulBackward0>)
# tensor(0.1477)

# %%
torch.save(srcnn,"srcnn.pkl")
print("123")
# Out:
# 123
